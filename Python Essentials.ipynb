# %%
from collections import defaultdict, Counter

#Sorting

x = [4,1,2,3]
y = sorted(x) #this leaves x unchanged

x.sort() # this changes x

#Sort list from largest to smallest:

x1 = sorted([-4,1,-2,3], key = abs, reverse=True)
print(x1)
# Out:
# [-4, 3, -2, 1]

# %%
#Dictionaries

#defaultdict is like a regular dictionary except that when you try to look up 
#a key it doesn't contain, it first adds a value for it using a zero-argument function you provided when you created it

dd_list = defaultdict(list)
dd_list[2].append(1)

print(dd_list.get(2))

dd_pair = defaultdict(lambda: [0,0])

dd_pair[3][0] = 12
dd_pair[2][1] =6

print(dd_pair)

c = Counter(dd_pair)

print(c)
# Out:
# [1]
# defaultdict(<function <lambda> at 0x000002079ED33CE0>, {3: [12, 0], 2: [0, 6]})
# Counter({3: [12, 0], 2: [0, 6]})

# %%
#Sets - Data structures which represent a collection of distinct elements

s = set()
s.add(1)
s.add(2)
print(len(s))
print(2 in s)
print(3 in s)

#Sets are used because in is a very fast operation on sets - fast and easy membership test

#Sets are also used to find distinct elements

item_list = [1,2,3,1]
item_set = set(item_list)

print(len(item_list))
print(f"Set has length {len(item_set)} whereas list has length {len(item_list)}")
print(item_set)
# Out:
# 2
# True
# False
# 4
# Set has length 3 whereas list has length 4
# {1, 2, 3}

# %%
#List comprehensions

even_numbers = [x for x in range(5) if x % 2 == 0]
squares = [x * x for x in range(5)]
even_squares = [x *x for x in even_numbers]

print(even_squares)

pairs = [(x,y) for x in range(4)
         for y in range(4)]

print(pairs)
# Out:
# [0, 4, 16]
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3), (3, 0), (3, 1), (3, 2), (3, 3)]

# %%
import random

# Randomness is deterministic, decided by internal state which can be set with random.seed(n)
# random.seed(3)
four_uniform_randoms = [random.random() for _ in range(4)]
print(four_uniform_randoms)

print(random.randrange(10))
print(random.randrange(3,6))

up_to_ten = [x for x in range(10)]
random.shuffle(up_to_ten)
print(up_to_ten)

print(random.choice(up_to_ten))

#choosing without replacement

print(random.sample(up_to_ten, 6))

#choosing with replacement

four_with_replacement = [random.choice(range(10)) for _ in range(4)]
print(four_with_replacement)
# Out:
# [0.2966193170375665, 0.9200249420468001, 0.2518206183215218, 0.17968775657208214]
# 1
# 3
# [4, 5, 3, 9, 8, 2, 7, 6, 1, 0]
# 9
# [8, 1, 2, 6, 3, 7]
# [5, 2, 5, 1]

# %%
#zip and Argument unpacking

list1 = ['a','b','c']
list2 = [1,2,3]

x = zip(list1, list2)
print(tuple(x))


# We can also unzip. * performs argument unpacking which uses the elements of pairs as individual arguments to zip

pairs = [('a', 1), ('b', 2), ('c', 3)]

letters, numbers = zip(*pairs)
print(letters)
print(list(numbers))
# Out:
# (('a', 1), ('b', 2), ('c', 3))
# ('a', 'b', 'c')
# [1, 2, 3]

# %%
#Defining functions of functions

#args is a tuple of unnamed arguments, kwargs is a dict of its named arguments

# def magic(*args, **kwargs):

def doubler(f):
    def g(*args,**kwargs):
        return 2 * f(*args, **kwargs)
    return g

def f2(x, y):
    return x + y

g = doubler(f2)
print(g(1,4))
# Out:
# 10

# %%
import numpy as np
import matplotlib.pyplot as plt

years = np.array([[1950, 1960, 1970, 1980, 1990, 2000, 2010]]).reshape(7,1)
gdp = np.array([300.2, 543.5, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3])


plt.plot(years, gdp, color="green", marker='x', linestyle ='solid')

plt.show()

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5,11,3,8,10]

xs = [i + 1 for i, _ in enumerate(movies)]

plt.bar(xs,num_oscars)

plt.ylabel("# of Academy awards")
plt.title("My Favourite movies")

plt.xticks([i + 1 for i, _ in enumerate(movies)], movies)
plt.show()

#Bar charts can also be a good choice for plotting histograms of bucketed numeric values, in order to visually explore how values are distributed

# %%
variance = [1,2,4,8,16,32,64,128,256]
bias_squared = [256,128,64,32,16,8,4,2,1]

total_error = [x + y for x, y in zip(variance,bias_squared)]

xs = [i for i, _ in enumerate(variance)]

plt.plot(xs, variance, 'gx-', label="variance")
plt.plot(xs, bias_squared, 'r-', label = "bias_squared")
plt.plot(xs, total_error, 'b:', label = "total_error")
plt.title("The Bias-Variance Tradeoff")
plt.legend(loc=9)

# %%
plt.scatter(variance, bias_squared)

# %%
from functools import reduce

def vector_add(v,w):
    return [v_i + w_i for v_i, w_i in zip(v,w)]

vector_add([1,2],[3,3])

#reduce(fun,seq) is used to apply a particular function passed in its argumet to all of the list elements:

def vector_sum(vectors):
    return reduce(vector_add, vectors)

vector_sum(([1,2],[3,4],[5,6]))
# Out:
# [9, 12]

# %%
import pandas as pd
import numpy as np
s1 = pd.Series([1,2,3,4,5])
type(s1)

s2 = pd.Series(np.arange(5), dtype = np.uint8)
print(s2)

s2.values
s2.array
s2.index
s2.dtype
s2.shape
s2.size
s2.nbytes
s2.ndim
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: uint8
# 1

# %%
data = {"city":['Bangalore', 'Bangalore', "Bangalore", "Mumbai", "Mumbai", "Mumbai"],
        "year":[2020, 2021, 2022, 2020, 2021, 2022],
        "population":[10.0, 10.1, 10.2, 5.2, 5.3, 5.5]}

df1 = pd.DataFrame(data)
print(df1)
df1.head()

df2 = pd.DataFrame(data, columns=["year", "city", "population"])
print(df2)
# Out:
#         city  year  population
# 0  Bangalore  2020        10.0
# 1  Bangalore  2021        10.1
# 2  Bangalore  2022        10.2
# 3     Mumbai  2020         5.2
# 4     Mumbai  2021         5.3
# 5     Mumbai  2022         5.5
#    year       city  population
# 0  2020  Bangalore        10.0
# 1  2021  Bangalore        10.1
# 2  2022  Bangalore        10.2
# 3  2020     Mumbai         5.2
# 4  2021     Mumbai         5.3
# 5  2022     Mumbai         5.5

# %%
df3 = pd.DataFrame()
df3['A'] = pd.Series(list(range(100)))
df3['B'] = np.random.randn(100,1)

df3

df3.plot(x='A',y='B')
plt.show()

# %%
df4 = pd.DataFrame(np.random.rand(10,4), columns = ['A','B','C','D'])

print(df4)

df4.plot.bar()
plt.show()
# Out:
#           A         B         C         D
# 0  0.091477  0.787917  0.000838  0.533637
# 1  0.953173  0.027300  0.323375  0.858338
# 2  0.515563  0.380862  0.543287  0.113081
# 3  0.786739  0.492841  0.243889  0.585612
# 4  0.706017  0.549490  0.279815  0.607862
# 5  0.939919  0.734153  0.139428  0.671354
# 6  0.190776  0.814269  0.923788  0.378893
# 7  0.556286  0.117764  0.225799  0.020358
# 8  0.381137  0.670854  0.182602  0.773593
# 9  0.704219  0.613141  0.971961  0.766535

# %%
df4.plot.barh()
plt.show()

# %%
df4.plot.bar(stacked=True)
plt.show()

# %%
df4.plot.hist(stacked=True,alpha=0.7,bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
from math import log10, floor

def round_sig(x, sig=30):
    return round(x, sig-int(floor(log10(abs(x))))-1)

def square(x):
    return x**2

arr = np.random.randn(3,7)*0.00001


vfunc = np.vectorize(round_sig)
result = vfunc(arr)
print(result)
# Out:
# [[-1.31302861e-06  1.14991309e-05  9.04413499e-06  3.58390329e-06
#    1.46330101e-05  7.68388690e-06  6.92303977e-06]
#  [-5.88033295e-06 -7.84384437e-06 -9.10383955e-06 -3.83633705e-06
#    3.02798510e-06  9.84494619e-08 -7.12015045e-07]
#  [-1.97079219e-05  1.79478186e-05  6.93365068e-06  6.87172142e-06
#   -2.59726698e-06 -2.21631710e-05  2.14471936e-06]]

# %%
"""
x_values = []
y_values = []
for _ in range(1000):
    x_values.append(random.randint(0,100))
    y_values.append(random.randint(0,100))
    plt.xlim(0,100)
    plt.ylim(0,100)
    plt.scatter(x_values, y_values)
    plt.pause(0.0001)

plt.show()

"""
# Out:
# '\nx_values = []\ny_values = []\nfor _ in range(1000):\n    x_values.append(random.randint(0,100))\n    y_values.append(random.randint(0,100))\n    plt.xlim(0,100)\n    plt.ylim(0,100)\n    plt.scatter(x_values, y_values)\n    plt.pause(0.0001)\n\nplt.show()\n\n'

# %%
# Integration in python
#with scipy.integrate. Gives trapezium & simpson's rules. 
#Go-to is quad. It is class with many methods.

from scipy.integrate import quad
quad(lambda x: 2*x+1,1,2)
#returns a tuple, (value of the integral, upper bound on the error)
#Need to use CAS such as sympy to get exact answer
# Out:
# (4.0, 4.440892098500626e-14)

# %% [markdown]
# Double and triple integrals: evaluating
#
# a) $\int_0^{2} \int_{x^2}^{2x} dydx$
#
# b) $\int_0^1 \int_0^{1-x} \int_0^{1-x-y} z dz dy dx$

# %%
#a
from scipy.integrate import dblquad
dblquad(lambda y, x: 1, #integrand - must be a function
        0, 2,           #outer limits
        lambda x: x**2, lambda x: 2*x) # inner limits
# Out:
# (1.3333333333333333, 1.4802973661668752e-14)

# %%
#b 
import numpy as np
from scipy.integrate import tplquad
tplquad(lambda z,y,x: z,
        0,1,
        0, lambda x: 1-x,
        0, lambda x,y: 1-x-y) #variables in reverse integration order!
# Out:
# (0.041666666666666664, 5.503056762889234e-15)

# %%
def integrand(z,r,t):
    return r

tplquad(lambda z, r, t: r,
        0, 2*np.pi,
        0, 1,
        lambda r: r**2, lambda r:3-2*r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 def integrand(z,r,t):
#       2     return r
# ----> 4 tplquad(lambda z, r, t: r,
#       5         0, 2*np.pi,
#       6         0, 1,
#       7         lambda r: r**2, lambda r:3-2*r)
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:964, in tplquad(func, a, b, gfun, hfun, qfun, rfun, args, epsabs, epsrel)
#     960     return [gfun(args[0]) if callable(gfun) else gfun,
#     961             hfun(args[0]) if callable(hfun) else hfun]
#     963 ranges = [ranges0, ranges1, [a, b]]
# --> 964 return nquad(func, ranges, args=args,
#     965         opts={"epsabs": epsabs, "epsrel": epsrel})
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1218, in nquad(func, ranges, args, opts, full_output)
#    1216 else:
#    1217     opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# -> 1218 return _NQuad(func, ranges, opts, full_output).integrate(*args)
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272, in _NQuad.integrate(self, *args, **kwargs)
#    1270 else:
#    1271     f = partial(self.integrate, depth=depth+1)
# -> 1272 quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#    1273               **opt)
#    1274 value = quad_r[0]
#    1275 abserr = quad_r[1]
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:464, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     461     return retval
#     463 if weight is None:
# --> 464     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     465                    points)
#     466 else:
#     467     if points is not None:
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:611, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     609 if points is None:
#     610     if infbounds == 0:
# --> 611         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     612     else:
#     613         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     614                                 epsabs, epsrel, limit)
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272, in _NQuad.integrate(self, *args, **kwargs)
#    1270 else:
#    1271     f = partial(self.integrate, depth=depth+1)
# -> 1272 quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#    1273               **opt)
#    1274 value = quad_r[0]
#    1275 abserr = quad_r[1]
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:464, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     461     return retval
#     463 if weight is None:
# --> 464     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     465                    points)
#     466 else:
#     467     if points is not None:
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:611, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     609 if points is None:
#     610     if infbounds == 0:
# --> 611         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     612     else:
#     613         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     614                                 epsabs, epsrel, limit)
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1262, in _NQuad.integrate(self, *args, **kwargs)
#    1260 ind = -(depth + 1)
#    1261 fn_range = self.ranges[ind]
# -> 1262 low, high = fn_range(*args)
#    1263 fn_opt = self.opts[ind]
#    1264 opt = dict(fn_opt(*args))
#
# File c:\Users\adam\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:956, in tplquad.<locals>.ranges0(*args)
#     955 def ranges0(*args):
# --> 956     return [qfun(args[1], args[0]) if callable(qfun) else qfun,
#     957             rfun(args[1], args[0]) if callable(rfun) else rfun]
#
# TypeError: <lambda>() takes 1 positional argument but 2 were given

# %% [markdown]
# -When defining the function in the integrand, the variables must be listed in the order of integration.
#
# -Limits of the integrals must all be defined as functions unless they are constants.
#
# -For tplquad, for the innermost limits, the variables in the functions must be listed in reverse order of integration.
#
# -As with quad, the output of dblquad and tplquad is a tuple: value of integral and upper bound of the absolute error.

# %%
grid = np.linspace(-3,3,7)
x, y = np.meshgrid(grid,grid)

u = lambda x,y: -y
v = lambda x,y: x

fig, ax = plt.subplots()
ax.quiver(x, y, u(x,y), v(x,y),
          units = 'xy', color='g', scale=3,
          pivot='tail')

plt.show()

# %%
tplquad(lambda z,y,x: y,
        0,2*np.pi,
        0, 1,
        lambda x,y: y**2, lambda x,y: 3-2*y) #variables in reverse integration order!
# Out:
# (3.6651914291880914, 4.0691799143434034e-14)
